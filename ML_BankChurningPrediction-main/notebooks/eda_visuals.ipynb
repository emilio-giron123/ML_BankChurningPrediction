# %% [markdown]
# # EDA Visuals Notebook
#
# This notebook runs the visualization workflow used by the main project code.
#
# The flow is:
# 1. Add the project root to `sys.path`.
# 2. Import the high-level visual generation function.
# 3. Generate all EDA figures and inspect the saved output paths.

# %%
# Import Path so the notebook can locate the project root folder.
from pathlib import Path
# Import sys so the notebook can add the project root to Python's import path.
import sys

# The notebook lives inside `notebooks/`, so the parent directory is the
# repository root where the `src/` package exists.
PROJECT_ROOT = Path.cwd().resolve().parent
# Append the project root only once so imports from `src` work in Jupyter.
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %% [markdown]
# ## Import the figure-generation function
#
# The next cell imports the single function that creates all EDA charts and returns the output file paths.

# %%
# Import the high-level function that creates every configured EDA figure.
from src.eda_visuals import generate_all_eda_visuals

# %% [markdown]
# ## Generate the visual outputs
#
# This cell runs the full chart-generation workflow.
#
# It creates the visual files and stores their paths in `generated_paths` so the notebook can display where each figure was saved.

# %%
# Run the end-to-end plotting workflow and store the output paths.
generated_paths = generate_all_eda_visuals()
# Display the returned list so the notebook shows which figure files were created.
generated_paths
